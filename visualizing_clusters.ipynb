# %%
from sklearn.externals import joblib
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

import sqlite3
from db_api import get_records_by_field

db = sqlite3.connect('db/users.db')
cursor = db.cursor()

# %%
cluster_fields = ['about', 'activities', 'books', 'communities',
                  'games', 'interests', 'personal_inspired_by', 'movies',
                  'music', 'status']

# %%
cluster_field = cluster_fields[3]
data = get_records_by_field(cursor, cluster_field)
ids, words = map(list, zip(*data))
flattened = [' '.join(sublist) for sublist in words]
# Out:
# total: 84995
# 0.0 0.05
# 0.0%
# 1.1765397964586153%
# 2.3530795929172306%
# 3.5296193893758456%
# 4.706159185834461%
# 5.882698982293076%
# 7.059238778751691%
# 8.235778575210306%
# 9.412318371668922%
# 10.588858168127537%
# 11.765397964586152%
# 12.941937761044768%
# 14.118477557503383%
# 15.295017353961997%
# 16.47155715042061%
# 17.648096946879228%
# 18.824636743337845%
# 20.001176539796457%
# 21.177716336255074%
# 22.35425613271369%
# 23.530795929172303%
# 24.70733572563092%
# 25.883875522089536%
# 27.06041531854815%
# 28.236955115006765%
# 29.41349491146538%
# 30.590034707923994%
# 31.76657450438261%
# 32.94311430084122%
# 34.11965409729984%
# 35.296193893758456%
# 36.47273369021707%
# 37.64927348667569%
# 38.8258132831343%
# 40.002353079592915%
# 41.178892876051535%
# 42.35543267251015%
# 43.53197246896876%
# 44.70851226542738%
# 45.88505206188599%
# 47.061591858344606%
# 48.238131654803226%
# 49.41467145126184%
# 50.59121124772045%
# 51.76775104417907%
# 52.944290840637684%
# 54.1208306370963%
# 55.29737043355492%
# 56.47391023001353%
# 57.65045002647214%
# 58.82698982293076%
# 60.003529619389376%
# 61.18006941584799%
# 62.35660921230661%
# 63.53314900876522%
# 64.70968880522383%
# 65.88622860168245%
# 67.06276839814107%
# 68.23930819459969%
# 69.4158479910583%
# 70.59238778751691%
# 71.76892758397553%
# 72.94546738043414%
# 74.12200717689277%
# 75.29854697335138%
# 76.47508676980999%
# 77.6516265662686%
# 78.82816636272722%
# 80.00470615918583%
# 81.18124595564446%
# 82.35778575210307%
# 83.53432554856168%
# 84.7108653450203%
# 85.88740514147891%
# 87.06394493793752%
# 88.24048473439615%
# 89.41702453085476%
# 90.59356432731337%
# 91.77010412377199%
# 92.9466439202306%
# 94.12318371668921%
# 95.29972351314784%
# 96.47626330960645%
# 97.65280310606506%
# 98.82934290252368%

# %%
vectorizer = TfidfVectorizer(max_df=0.3, min_df=0.005)
X = vectorizer.fit_transform(flattened)

# %%
true_k = 20

model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1, verbose=1)
model.fit(X)
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print(i)
    st = ''
    arr = []
    for ind in order_centroids[i, :25]:
        arr.append(terms[ind])
    print(' '.join(arr))
    print()
# Out:
# Top terms per cluster:
# 0
# животные животным животных бездомных им собак требуется отлов страдают живущих приводит станьте животными делать семью способом помогают кошек друг улице стороны помощь находят помочь случае
#
# 1
# комментарии размещению vkcomekbrepost коммерческому удаляются оставлять предлагать vkcompage менеджеру почему подпишитесь страницу урала нашу происшествия паблика несчастного пожара свидетелем аварии vkcomkalininamarinka incekb разбану случая пожаловаться
#
# 2
# новостей мемы приколы типичный эксклюзивам серьёзное котиков типичного оперативности ежедневную xaхалеву idмилолике teekb idсeргeю третьяковой произошло концепция предлагаемые использовании качеству обязательна пользу такая расскажем обратиться
#
# 3
# палаты её хэштегов читая сможешь эмоций можешь стену можем мой среди значит друг тебе тебя когда читать присылают откровений прочитанного моментами читатели откровения откровение сумасшествия
#
# 4
# детей родителей мам рецепты ребенка дети мастеров родители мама здоровье ярмарка найдете детских идей товаров детские мастерклассы полезные психология детская httpsvkcomtopic беременность материнство семье читайте
#
# 5
# httpsvkcomalbum маникюр ногтей маникюра ногти дизайн гель френч модные новинки дизайна белый стразами тенденции ногтях лак мастеров aliexpress зима товары зимний нежный модный тд красный
#
# 6
# the of and house deep techno in to music is dj for музыки with progressive minimal музыка tech as on dance we trance world disco
#
# 7
# рецепты mvkcomwrite сотрудничестве предложениями обращайтесь вкусные товаров инструкциями пошаговыми услуг разместить менеджеру рекламу блюда компании домашние простые вкус фотографиями тегам блюд идей рецептов пшённой cookbon
#
# 8
# график розничный магазин трк этаж шоурум проспект шоссе тц пр руб ежедневно доставка всеволожский сходненская кад ленинградская заказы ул корп предоплату мега корпус пределах трц
#
# 9
# арт art тату хаус граффити рисунки креатив картины искусство фотография iloveart искусстве фотошоп архитектура музыка творчество прекрасного кино контакте вдохновение ценителей искусства дизайн настоящих первый
#
# 10
# ноября марта ночь февраля теми декабря января the абстрасенция clubrsac clubmotorama clubkedr livanskiy clubcosmic clublizer clubfetre clubghostemane clubbogachi clubсбпч clubсансара clublumen воротилами clubrodriguez clubмальбэк clubten
#
# 11
# вещи бан хэштег вещь httpsvkcomalbum ссылки забрать указывать готовы отдающим забивайте забирающим уведомите явиться передумали попытку забили скрытую забирать скрытый сообщайте комментарием собираетесь прикреплять дар
#
# 12
# ул тел году игры клуб место телефон области эта авто доставка этой объявления наша друзей является музыка событий фотографии компания он httpsvkcomtopic присоединяйтесь бан школы
#
# 13
# фильмы новинки подписывайся журнал рецепты юмор кино гороскоп смотри тебе идей заходи познавательный будь спасибо тебя юмора психология мысли подписывайтесь hd факты умный вк первый
#
# 14
# топе просмотров поста эффективность постов размещение руб ссылок объявления суперактивная modlekb термоядерной сылками феноменальный феноменальная сравните датчик конкурентами упустите целевая почувствуйте пакет разницу моделей платно
#
# 15
# httpsvkmeprobizportal настроить помогут встречи консультации помочь периодичные консультационнопознавательный психологомигропрактиком probizportal ботсекретарь нетворкингклуба трансформационной видеоурок постарается cashflow предпринимательский бизнеспроцессы консультанта проведут наташа bb верных личностному статью
#
# 16
# анонимно никогда читать разнятся высокоморальны впечатлительны возвращайтесь закройте особенная откровением совпадает людских откровениями жизненными строк ситуациями аудиторией ежедневный еды огромной httpsideerrusecretsadd overhear секретами подслушано зачастую
#
# 17
# рекламы должна wwwinstagramcombestadvt bestad wwwchatsvibercomadv найки wwwfacebookcombestadvt wwwtelegrammebestad wwwyoutubecomchannelucsettyknplsthhbbresg увлекать отвлекать артпроектами шедеврам реакцией развлекать наружной постеров органично собирают статьями попрежнему сочетаются описать роликов сказал
#
# 18
# объявления химмаше пр паблика содержащие химмаш стене ср вт публикуются чт пн котором пт ваше сб объявление вс обсуждениях бан рекламные попровинциальному химмашавто поообщаться химмашдомострой
#
# 19
# ул тел доставка году httpsvkcomtopic он наша центр телефон руб заказ этаж объявления часы человек сделать сайте место детей адрес фотографии клуб хотите является себе

# %%
true_k = 30

model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1, verbose=1)
model.fit(X)
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print(i)
    st = ''
    arr = []
    for ind in order_centroids[i, :25]:
        arr.append(terms[ind])
    print(' '.join(arr))
    print()
# Out:
# Initialization complete
# Iteration  0, inertia 83970.798
# Iteration  1, inertia 78347.516
# Iteration  2, inertia 77612.692
# Iteration  3, inertia 77331.816
# Iteration  4, inertia 77207.202
# Iteration  5, inertia 76993.982
# Iteration  6, inertia 76881.870
# Iteration  7, inertia 76751.210
# Iteration  8, inertia 76669.362
# Iteration  9, inertia 76636.819
# Iteration 10, inertia 76615.952
# Iteration 11, inertia 76604.985
# Iteration 12, inertia 76600.870
# Iteration 13, inertia 76599.200
# Iteration 14, inertia 76597.775
# Iteration 15, inertia 76596.072
# Iteration 16, inertia 76593.955
# Iteration 17, inertia 76590.684
# Iteration 18, inertia 76584.563
# Iteration 19, inertia 76571.111
# Iteration 20, inertia 76552.341
# Iteration 21, inertia 76546.025
# Iteration 22, inertia 76540.088
# Iteration 23, inertia 76526.661
# Iteration 24, inertia 76485.249
# Iteration 25, inertia 76345.609
# Iteration 26, inertia 76282.050
# Iteration 27, inertia 76233.486
# Iteration 28, inertia 76186.550
# Iteration 29, inertia 76158.232
# Iteration 30, inertia 76144.546
# Iteration 31, inertia 76133.969
# Iteration 32, inertia 76125.356
# Iteration 33, inertia 76118.880
# Iteration 34, inertia 76114.274
# Iteration 35, inertia 76111.109
# Iteration 36, inertia 76108.152
# Iteration 37, inertia 76102.832
# Iteration 38, inertia 76096.780
# Iteration 39, inertia 76092.602
# Iteration 40, inertia 76089.960
# Iteration 41, inertia 76087.804
# Iteration 42, inertia 76085.265
# Iteration 43, inertia 76084.098
# Iteration 44, inertia 76083.678
# Iteration 45, inertia 76083.363
# Iteration 46, inertia 76083.091
# Iteration 47, inertia 76082.910
# Iteration 48, inertia 76082.809
# Iteration 49, inertia 76082.713
# Iteration 50, inertia 76082.627
# Iteration 51, inertia 76082.560
# Iteration 52, inertia 76082.503
# Iteration 53, inertia 76082.430
# Iteration 54, inertia 76082.368
# Iteration 55, inertia 76082.315
# Iteration 56, inertia 76082.264
# Iteration 57, inertia 76082.217
# Iteration 58, inertia 76082.171
# Iteration 59, inertia 76082.112
# Iteration 60, inertia 76082.019
# Iteration 61, inertia 76081.871
# Iteration 62, inertia 76081.689
# Iteration 63, inertia 76081.460
# Iteration 64, inertia 76081.098
# Iteration 65, inertia 76080.678
# Iteration 66, inertia 76080.330
# Iteration 67, inertia 76080.075
# Iteration 68, inertia 76079.945
# Iteration 69, inertia 76079.874
# Iteration 70, inertia 76079.822
# Iteration 71, inertia 76079.795
# Iteration 72, inertia 76079.765
# Iteration 73, inertia 76079.730
# Iteration 74, inertia 76079.703
# Iteration 75, inertia 76079.688
# Iteration 76, inertia 76079.678
# Iteration 77, inertia 76079.670
# Iteration 78, inertia 76079.664
# Iteration 79, inertia 76079.660
# Iteration 80, inertia 76079.657
# Iteration 81, inertia 76079.655
# Iteration 82, inertia 76079.652
# Iteration 83, inertia 76079.651
# Iteration 84, inertia 76079.650
# Converged at iteration 84: center shift 0.000000e+00 within tolerance 7.094932e-09
# Top terms per cluster:
# 0
# золотой ban ул тел касается доб publicofmusic сеть ювелирная enter объявлений магазинов скидки выгодно федеральная развивающие наша делать развлечения вакансии украшения развитию поста несет этого
#
# 1
# палаты её хэштегов читая сможешь эмоций можешь стену можем мой среди значит тебе тебя друг когда читать присылают откровений прочитанного читатели откровение сумасшествия окунёшься испытаешь
#
# 2
# httpsvkcomalbum вещи отдам разово подопечным семьям указывайте основном любому ранее нужна район администратору мамы готовы контакты помощи написать объявление какой помощь либо сразу сами смотрите
#
# 3
# футболе полюби футбола футбол мск размещению знаменитые позитивным предоставлять политическую гк приходилось goal vkcomekbrepost коммерческому ufcargentina дискография знаем волны дилер vs meduzaproject смешанных чрезмерное авторского
#
# 4
# зоозащита mirfactov style архитектура justcook beauty арт bon креатив fashion art рекламы статьями напишите должна zoozahita тренажеры лекарствами неизведанные живота literabook vktravel mirreklami финансами нестандартная
#
# 5
# новостей мемы приколы серьёзное котиков ежедневную типичный эксклюзивам типичного оперативности произошло idсeргeю idмилолике xaхалеву teekb третьяковой концепция предлагаемые использовании качеству обязательна пользу такая расскажем присылайте
#
# 6
# deutsch немецкого языка учеников преподавателей немецком точки данный проводим немецкий школа момент германии интернет обучение online vkcomvideossectionalbum видеозапись барьер start урока офлайн диванчике экзаменов учите
#
# 7
# ярмарка мастеров покупателей мастера работ хендмейд площадка торговая белоруссии авторских пользователей помогут удовольствием форме портал товаров числе вязание livemasterru livemasterruquestions httpswwwlivemasterruforsellers ливмастер livemaster дополняющие впечатляющей
#
# 8
# съемки съемку go фотографы фишка оплачиваете успели сбвс пнпт выходные места радуетесь бронируете акцию секунды чистую радуемся обрабатываем процессу съемочной текущих забудем налоги смеемся высочайшего
#
# 9
# график розничный магазин трк этаж шоурум проспект шоссе тц пр руб ежедневно доставка всеволожский сходненская кад ленинградская заказы ул корп предоплату мега корпус пределах трц
#
# 10
# since ep the in place on top techno prodigy force стойки house label fb мебель live шкафы records of up radio мебели music big изделия
#
# 11
# тегам можешь марафонляжкиooo грудьooo питаниеooo прессooo советыooo растяжкаooo удивимарафонooo рукиooo ппooo ногиooo животooo спинаooo марафонпопаooo марафоннпзooo тренировкаooo нгмарафонooo рецептыooo марафонooo талияooo попаooo уверенней изнурительных переживай
#
# 12
# году безопасно ep темах high взаимодействия выборы денис купоны sound сергея расширяем вещах российской сознание барахолка of россию распродажи соответствующие треки you низкие родился it
#
# 13
# ул тел детей доставка году httpsvkcomtopic он центр наша заказ телефон руб клуб сайте сделать человек себе адрес место является меня области фотографии этой хотите
#
# 14
# животные животным животных бездомных им собак требуется отлов страдают живущих приводит станьте животными делать семью способом помогают кошек друг улице стороны помощь находят помочь случае
#
# 15
# премий влиятельных актриса песен джаз леди американская mtv номинации композитор мнению популярная forbes золотой альбома премии автор премьера настоящее журнала одна имя новостей фильмы редактор
#
# 16
# вещи бан вещь ссылки забивайте забирающим уведомите отдающим явиться передумали забили скрытую попытку забирать скрытый сообщайте комментарием собираетесь прикреплять встречу дар отдать забрать постах указывать
#
# 17
# mash способов новинки блюд она рф музыка характер магазинов блюда исключительно найдёте снежинск несущих почувствуете нити оживляет приема американской оставят восторг вне сервировки тишины богатства
#
# 18
# ноября марта ночь февраля теми декабря января the абстрасенция clubrsac clubmotorama clubkedr livanskiy clublumen clubмальбэк clubкняzz clublizer clubghostemane clubfetre воротилами фэшнредакторами clubлуна clubten clubrodriguez clubсансара
#
# 19
# httpsvkcomalbum маникюр ногтей маникюра ногти дизайн гель френч модные новинки дизайна белый стразами тенденции ногтях лак aliexpress зима мастеров товары зимний нежный модный тд красный
#
# 20
# the of and house deep techno in to music is dj музыки for with музыка progressive minimal tech as we dance world on trance году
#
# 21
# рецепты фильмы новинки журнал подписывайся идей юмор кино тебе детей подписывайтесь смотри будь заходи спасибо найдете музыка тебя полезные фотографии гороскоп первый товаров дома дизайн
#
# 22
# топе просмотров поста эффективность постов размещение ссылок руб объявления суперактивная modlekb термоядерной сылками феноменальный феноменальная сравните датчик конкурентами упустите целевая почувствуйте пакет разницу моделей платно
#
# 23
# объявления химмаше пр паблика содержащие химмаш стене ср вт публикуются чт пн котором пт ваше сб объявление вс обсуждениях рекламные бан химмашавто химмашдаром himmashekb поообщаться
#
# 24
# комментарии объявления посты страницу оставлять удаляются анонимно размещению предлагать vkcomekbrepost коммерческому бан почему подпишитесь хэштег менеджеру паблика нашу vkcompage публикуем объявление урала никогда читать контент
#
# 25
# рекламы должна wwwfacebookcombestadvt wwwtelegrammebestad wwwchatsvibercomadv wwwinstagramcombestadvt найки bestad wwwyoutubecomchannelucsettyknplsthhbbresg увлекать отвлекать артпроектами шедеврам реакцией развлекать наружной постеров органично собирают статьями попрежнему сочетаются описать роликов сказал
#
# 26
# стероидов спортивной употребление личности выздоровление хуеты неумолимость никотиновых неявной сопровождающей несущую лечь экспансии присущие стальной алкоголиков элиты разрушение стержень слабой лишённый наркоманов крепкий анаболических yourfuture
#
# 27
# светиться жителях просьбу поделиться вакансиях модерируются рубрикам ближайших соседями сообщением районе опубликовать прочитать жмите событиях историями анонимно объявление сообщение автора фотографиями обсуждениях задать качестве домом
#
# 28
# часы трк тел ул выходных этаж сб офис марта bankturovbankturov cити кассовая кунавина пиццерия вылеты петровский халтурина владивостока специалистом ориентир цокольный мегаполис банке карнавал туристических
#
# 29
# палаты мамы развивается материнство женщины семье разные моментами откровения друг правильными случиться критического долго замечательное её необычной ребёнку веселой ситуацией радостей хэштегов достигает поддержим конкретным

# %%
from clustering import load_model
model = load_model('communities.pkl')
vec = load_model('communities_vec.pkl')
# Out:
# /home/ftlka/.local/lib/python3.5/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator KMeans from version 0.20.0 when using version 0.20.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
X = vec.transform(['музыка'])
model.predict(X)
# Out:
# array([33], dtype=int32)

# %%
true_k = 40
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vec.get_feature_names()
for i in range(true_k):
    print(i)
    st = ''
    arr = []
    for ind in order_centroids[i, :25]:
        arr.append(terms[ind])
    print(' '.join(arr))
    print()
# Out:
# Top terms per cluster:
# 0
# знакомства общение общения знакомств друзей встречи девушки любовь свою отношений познакомиться создана реальные себе девушек чат объявления вступайте возраст друзья любви поиск фотографии анонимно людьми
#
# 1
# объявления объявлений объявление доска продаже продать размещайте барахолка стене купить размещения бесплатно частные продам размещать бесплатные размещение публикуются авто куплю разместить репост бан покупке бесплатных
#
# 2
# такое когда знает он снова ли бы вот еще даже любовь человека тебя себе она да именно том этот кого нужно этого люди этой бывает
#
# 3
# премьера сериал сезона октября фильма ноября сезон фильм песни сентября сша декабря февраля году марта нового official шоу концертов серии тнт канале апреля мая год
#
# 4
# будут удаляться опубликованы этой бан фотографии конкурсы участников посты стене будем проходить друзья рады игры либо других материалы ссылки внимание администрация создана предлагайте участники выкладывать
#
# 5
# тел ул адрес этаж mail пн пт адресу вс сб тц телефон офис магазин режим запись ленина пр центр находимся работаем вход дом оф выходной
#
# 6
# руб рождения вход читают душой сентября начало клубе скидка русской этому больших стала находимся стихи компаний говорить песни билеты этаж вот несколько места потому тот
#
# 7
# ремонт обслуживание сложности квартир авто техники автомобилей тел любой работ ключ услуги запчасти ремонта автомобиля гарантия ремонту продажа строительство оборудования тюнинг ул виды iphone качественно
#
# 8
# заказ магазин компания руб услуги цены товары ценам работаем рублей наличии телефону звоните заказы любой заказать компании купить ассортимент предлагаем волос качество оформление продукции телефон
#
# 9
# online public любителей клуб youtube игры сюда official любит of love art тебя group фотографии предлагайте подписывайтесь юмор заходи картинки канал вступайте свежие многое будь
#
# 10
# ресниц волос маникюр ногтей педикюр макияж гель запись услуги оформление обучение тел мастер материалы красоты руб прически массаж телефону студия виды ул лица мастера класса
#
# 11
# клиентов цвет волос снова красоту хотите мне раз ваших начинает большую ти решили сохранить когда зарабатывать могли клиентам опт звонок подходит задач насколько дать образом
#
# 12
# меня зовут мне буду привет рада мои работаю мой моей здравствуйте занимаюсь ко моя мной хочу фотограф могу видеть люблю выкладывать мастер этой лс друзья
#
# 13
# the in and of this russian to решения is you for on область best we world all are it music by new your welcome one
#
# 14
# ну конечно вот да бы там мне кому сюда будем привет еще когда кого эта люди меня друзей любит ещё буду тоже вообще этой будут
#
# 15
# школы класса школа выпускников школе school родителей класс школу детей занятия обучение году этой обучения ул эта создана классов родители образования курсы адрес год после
#
# 16
# изготовление заказ изделий мебели сложности любой доставка заказы тел продажа производство ремонт вашим разработка изделия оформление дизайн mail услуги мастерская авто продукции любых индивидуальный ручной
#
# 17
# studio студии творчества рублей сайте бронирование творческие календарь пространство открыты больших проведения аренда провести уютное находимся дни час проектов два лс рождения настроение расписание стоимость
#
# 18
# стоимость заказ посмотреть доставка сайте либо приготовления рецепты месяца забрать сроки страничке заявки нашему by образом принимаются недели каждая таким оставить заявку готовим приветствовать ознакомиться
#
# 19
# рукоделия творческие классов идея желающих мастер проведения формате делиться мастеров творчества клуб целиком могу формат сборник буду оставить виды хочется встречи программа петербурге рада другу
#
# 20
# читает книги рэп он любит да тому статус сейчас тот стихи здоровья читать этот любви тем лекции меня автор никто книга лишь книг книгу сюда
#
# 21
# доставка бесплатная заказ всей наличии магазин заказа почтой руб оплата цены заказе доставки рублей заказы ценам рф товар дней екатеринбургу бесплатно товара получении ассортимент городу
#
# 22
# друзей приглашайте своих вступайте приглашаем друзья сюда новых ваших вступай рады будем этой добавляйте лайки близких эта создана нашу любит давайте друзьям эту тем подписывайтесь
#
# 23
# music музыка and музыки the of deep house for is new rock музыку to art life best only my dance треки your soul in музыкальный
#
# 24
# спорта видов вид спорт спортивных любителей sport спортивные виды отдыха футбол федерации клуб тренировки области спортивный мастер образа развитие здорового занятия организация спортивного тренер фитнес
#
# 25
# ручной изделия украшения заказ подарки подарок игрушки аксессуары изделий наличии доставка заказать близких заказы авторские приобрести мастерская эксклюзивные любовью handmade вещи любой свадебные оригинальные вашему
#
# 26
# лиц старше материалы ответственности права администрация исключительно частных услуги целях строго ти вход прав заявку никакой несет право помощь услуг является данная контент рф либо
#
# 27
# одежда обувь детская наличии одежды аксессуары заказ женская доставка ценам магазин одежду товары платья всей вещи детей мужская цены игрушки брендов доступным ассортимент почтой косметика
#
# 28
# продажа покупка обмен недвижимости аренда запчастей авто производство автомобилей оборудования доставка тел заказ купить наличии ценам услуги аксессуаров квартир техники недвижимость вещей запчасти обслуживание продать
#
# 29
# дата создания рождения имя рост место см сентября апреля ноября августа июля февраля год октября июня мая марта декабря января полное сша настоящее клуб цвет
#
# 30
# интеллект проблем русской национальной понимать наша традиции которыми культуре знание страна внимания той вообще основная russian максимально вернуться личных реальность находится связи взгляд надо публикации
#
# 31
# культуры искусства фестиваль центр области году является русской развитие образования центра дом музыки развития участие ул организация современной деятельности хип творчества коллектив спорта им мероприятий
#
# 32
# будут вечеринки утра бар отличное гостей игр info настроение множество выбор атмосфера жить котором большой цены адрес место музыка каждым кажется какая какие каким каждому
#
# 33
# музыка dj house deep музыки вход go лучшая музыку ночь dance music tech начало треки души клуб бесплатный электронной free ул face музыкой рок rock
#
# 34
# он этой когда рады будем друзья бы году свою себе человек место детей наша этот человека был люди да она ее этого либо даже нужно
#
# 35
# мебель мебели кухни заказ производство изготовление интерьера тел дома детские дизайн доставка производителя изделия компания любой цены вашим ценам магазин качество mail ул работаем интерьер
#
# 36
# наше дух мебель чт приходите график огромный тренды популярный ярких гости район ли пт атмосферу сб любим вс меню кого выбор ещё те разных новое
#
# 37
# вдохновения источник мастер творчества классы вашего идей настроения схемы порция найдете ежедневная art творчество вдохновение поисках твоего фотографии место творческих дизайнеров пространство искусство рукоделия подборки
#
# 38
# создана эта любит общения посвящена данная обмена любителей кому целью была хочет специально кого опытом этой информацией наша бы будем друзья обсуждения дорогие рады давайте
#
# 39
# люблю меня тебя мне мои зовут привет буду мой хочу моя когда свою рада могу любовь моей своих да фотограф он спасибо делать музыку иногда

# %%
model.get_params()
# Out:
# {'algorithm': 'auto',
#  'copy_x': True,
#  'init': 'random',
#  'max_iter': 300,
#  'n_clusters': 40,
#  'n_init': 10,
#  'n_jobs': None,
#  'precompute_distances': 'auto',
#  'random_state': None,
#  'tol': 1e-07,
#  'verbose': True}

# %%
print(len(list(vec.stop_words_)))
'кино' in vec.stop_words_
# Out:
# 952841
# False

# %%
print(len(list(vec.vocabulary_)))
vec.vocabulary_
# Out:
# 3143
# {'girls': 85,
#  'миллионами': 1367,
#  'na': 157,
#  'портал': 1974,
#  'практически': 2034,
#  'исключительно': 998,
#  'сотрудничестве': 2601,
#  'снять': 2541,
#  'источник': 1021,
#  'кафе': 1061,
#  'направлениям': 1474,
#  'традиции': 2823,
#  'сложные': 2514,
#  'свобода': 2424,
#  'it': 121,
#  'твоих': 2744,
#  'эксклюзивные': 3103,
#  'крупный': 1192,
#  'оставлять': 1721,
#  'граждан': 605,
#  'info': 114,
#  'темах': 2782,
#  'стараемся': 2653,
#  'бронирование': 388,
#  'нравится': 1586,
#  'хочет': 3011,
#  'сладкие': 2503,
#  'rem': 197,
#  'магазине': 1296,
#  'art': 16,
#  'услуги': 2923,
#  'употребление': 2907,
#  'мебели': 1334,
#  'делайте': 658,
#  'правда': 2020,
#  'сохранить': 2604,
#  'поисках': 1889,
#  'напрямую': 1476,
#  'каждым': 1040,
#  'твои': 2743,
#  'ваше': 418,
#  'свадебные': 2411,
#  'шапке': 3090,
#  'забывайте': 837,
#  'пробуй': 2108,
#  'высказывания': 547,
#  'оперативности': 1678,
#  'esquire': 60,
#  'практические': 2035,
#  'качественный': 1067,
#  'эмоции': 3109,
#  'теме': 2783,
#  'свадебный': 2412,
#  'pubauto': 191,
#  'отношений': 1760,
#  'любому': 1280,
#  'каменск': 1049,
#  'красивый': 1173,
#  'понедельника': 1954,
#  'услуг': 2920,
#  'многие': 1388,
#  'улица': 2897,
#  'минимум': 1372,
#  'search': 206,
#  'товары': 2809,
#  'полной': 1919,
#  'фейл': 2956,
#  'тест': 2792,
#  'отдам': 1740,
#  'хотите': 3007,
#  'назад': 1456,
#  'kaif': 125,
#  'основан': 1707,
#  'выгодные': 539,
#  'любимые': 1263,
#  'деятельность': 690,
#  'создаем': 2575,
#  'сроки': 2638,
#  'умные': 2899,
#  'всея': 518,
#  'мам': 1306,
#  'первого': 1795,
#  'дешевые': 688,
#  'словом': 2512,
#  'another': 9,
#  'канале': 1052,
#  'обучение': 1627,
#  'самого': 2394,
#  'события': 2556,
#  'кроме': 1185,
#  'мужской': 1433,
#  'музыкальный': 1438,
#  'любопытство': 1281,
#  'создано': 2581,
#  'стран': 2679,
#  'сделайте': 2445,
#  'крутой': 1194,
#  'dom': 54,
#  'производителей': 2144,
#  'инстаграм': 963,
#  'пользователи': 1935,
#  'ранее': 2275,
#  'самая': 2390,
#  'сообщением': 2585,
#  'pikabu': 178,
#  'заранее': 876,
#  'ответы': 1738,
#  'добавляют': 708,
#  'черный': 3068,
#  'женского': 807,
#  'книгу': 1099,
#  'активно': 298,
#  'пермь': 1806,
#  'языком': 3138,
#  'комедия': 1116,
#  'силу': 2483,
#  'жить': 828,
#  'искренне': 999,
#  'возвращайтесь': 482,
#  'сайты': 2386,
#  'читайте': 3075,
#  'вступить': 526,
#  'желательно': 802,
#  'нашего': 1512,
#  'крупнейшее': 1188,
#  'уральский': 2913,
#  'желающих': 803,
#  'humor': 104,
#  'продаже': 2127,
#  'ру': 2357,
#  'книг': 1095,
#  'пздц': 1812,
#  'моменты': 1420,
#  'крупнейших': 1190,
#  'ей': 784,
#  'почту': 2010,
#  'дни': 702,
#  'имени': 948,
#  'никто': 1553,
#  'обучения': 1628,
#  'вк': 462,
#  'можем': 1410,
#  'утра': 2929,
#  'летать': 1226,
#  'район': 2269,
#  'администратору': 287,
#  'новому': 1568,
#  'взрослых': 452,
#  'подписались': 1855,
#  'женщина': 812,
#  'подписался': 1856,
#  'известные': 935,
#  'полезную': 1910,
#  'чат': 3056,
#  'напиши': 1469,
#  'стену': 2664,
#  'родители': 2340,
#  'ноги': 1577,
#  'подход': 1871,
#  'соц': 2605,
#  'первой': 1797,
#  'узнай': 2889,
#  'ответственности': 1736,
#  'саморазвитие': 2397,
#  'глаза': 572,
#  'команды': 1115,
#  'названием': 1458,
#  'shkola': 209,
#  'проектов': 2142,
#  'обсуждения': 1622,
#  'ему': 787,
#  'ужасы': 2884,
#  'nails': 158,
#  'курсе': 1207,
#  'design': 49,
#  'go': 88,
#  'изготовление': 938,
#  'декабря': 651,
#  'навигация': 1450,
#  'пользоваться': 1936,
#  'хорошего': 2997,
#  'целую': 3026,
#  'выше': 556,
#  'вокруг': 489,
#  'статей': 2656,
#  'отдых': 1744,
#  'флуд': 2968,
#  'мед': 1337,
#  'публиковать': 2197,
#  'трясутся': 2841,
#  'шооок': 3099,
#  'нужно': 1590,
#  'общем': 1632,
#  'лучшему': 1252,
#  'еду': 772,
#  'работать': 2221,
#  'адрес': 292,
#  'помните': 1941,
#  'материалов': 1327,
#  'портфолио': 1976,
#  'комфортно': 1130,
#  'vkontakte': 245,
#  'является': 3132,
#  'просторах': 2162,
#  'дарим': 630,
#  'des': 48,
#  'размещения': 2261,
#  'еды': 773,
#  'красоты': 1179,
#  'вкусные': 467,
#  'телеграм': 2765,
#  'twitter': 236,
#  'людям': 1291,
#  'статусы': 2658,
#  'доме': 723,
#  'серьёзное': 2477,
#  'дизайна': 694,
#  'найди': 1462,
#  'povar': 183,
#  'банк': 341,
#  'тысяч': 2852,
#  'стань': 2652,
#  'скидок': 2498,
#  'взгляд': 450,
#  'приколы': 2078,
#  'родителей': 2339,
#  'найдешь': 1461,
#  'домом': 726,
#  'interior': 117,
#  'ситуации': 2487,
#  'уважением': 2860,
#  'женщины': 813,
#  'аудитория': 336,
#  'ссср': 2639,
#  'сотрудничеству': 2603,
#  'текст': 2760,
#  'ближайших': 366,
#  'работает': 2220,
#  'увидите': 2865,
#  'далеко': 620,
#  'любовь': 1274,
#  'обсудить': 1617,
#  'мегаполиса': 1336,
#  'анонимно': 317,
#  'индивидуально': 955,
#  'лучше': 1249,
#  'общество': 1637,
#  'посредников': 1988,
#  'женская': 804,
#  'кино': 1077,
#  'ютуб': 3129,
#  'собрана': 2547,
#  'сможешь': 2530,
#  'происходит': 2150,
#  'homeideaz': 100,
#  'частные': 3050,
#  'временем': 510,
#  'fashion': 69,
#  'женские': 805,
#  'занимается': 860,
#  'dance': 45,
#  'детей': 674,
#  'блюда': 371,
#  'сегодня': 2450,
#  'стоимость': 2672,
#  'проект': 2138,
#  'прочие': 2182,
#  'почта': 2007,
#  'сторону': 2677,
#  'получения': 1930,
#  'такой': 2733,
#  'животных': 819,
#  'лайфхаки': 1217,
#  'дети': 675,
#  'экспонат': 3106,
#  'столица': 2674,
#  'вход': 531,
#  'одного': 1658,
#  'channel': 38,
#  'сколько': 2499,
#  'тематике': 2778,
#  'маникюра': 1310,
#  'специалисты': 2617,
#  'декора': 653,
#  'семья': 2465,
#  'труд': 2840,
#  'твори': 2746,
#  'интерьера': 988,
#  'магазинов': 1297,
#  'сложности': 2513,
#  'tape': 221,
#  'декоре': 654,
#  'родителями': 2341,
#  'поиске': 1890,
#  'внимание': 476,
#  'соблюдать': 2545,
#  'городу': 595,
#  'hd': 95,
#  'хотел': 3004,
#  'реальность': 2292,
#  'бизнесе': 359,
#  'связь': 2442,
#  'точно': 2822,
#  'нашими': 1515,
#  'читай': 3074,
#  'черного': 3067,
#  'красоту': 1178,
#  'вещи': 448,
#  'получается': 1926,
#  'кнопка': 1100,
#  'диетах': 691,
#  'научиться': 1495,
#  'делает': 657,
#  'вот': 504,
#  'такое': 2732,
#  'удобное': 2879,
#  'опыт': 1690,
#  'служба': 2515,
#  'данных': 628,
#  'своё': 2435,
#  'покупка': 1900,
#  'проблем': 2106,
#  'должно': 717,
#  'лучшей': 1251,
#  'оборудования': 1606,
#  'подобрать': 1854,
#  'здравствуйте': 896,
#  'пропаганда': 2153,
#  'положительных': 1924,
#  'профессиональные': 2174,
#  'земле': 897,
#  'детским': 680,
#  'ps': 187,
#  'автомобиль': 274,
#  'ссылки': 2643,
#  'этим': 3115,
#  'моментами': 1419,
#  'детский': 679,
#  'тема': 2776,
#  'курс': 1205,
#  'салон': 2387,
#  'обсуждение': 1620,
#  'интересная': 970,
#  'футбол': 2986,
#  'данные': 626,
#  'креативный': 1183,
#  'leprum': 131,
#  'которых': 1163,
#  'оскорбление': 1703,
#  'жителей': 827,
#  'опт': 1685,
#  'ответим': 1734,
#  'ремонт': 2318,
#  'on': 168,
#  'hmideas': 98,
#  'песни': 1808,
#  'fitness': 72,
#  'групповые': 610,
#  'др': 740,
#  'размещению': 2260,
#  'кстати': 1197,
#  'главные': 569,
#  'меня': 1346,
#  'бесплатно': 351,
#  'говорить': 576,
#  'сообществ': 2588,
#  'новостей': 1569,
#  'косметика': 1150,
#  'travel': 234,
#  'немного': 1530,
#  'школы': 3097,
#  'индивидуальность': 956,
#  'ознакомиться': 1664,
#  'ждет': 795,
#  'аудио': 333,
#  'креативные': 1182,
#  'материал': 1325,
#  'низкокалорийные': 1547,
#  'информационно': 991,
#  'размещаем': 2255,
#  'друг': 742,
#  'провести': 2113,
#  'любимым': 1265,
#  'ребёнка': 2297,
#  'сети': 2478,
#  'одежды': 1652,
#  'местах': 1354,
#  'работают': 2223,
#  'первое': 1796,
#  'описание': 1679,
#  'января': 3139,
#  'нашему': 1513,
#  'посетить': 1983,
#  'любим': 1260,
#  'тнт': 2804,
#  'свадьба': 2413,
#  'преимущества': 2057,
#  'leprazo': 130,
#  'порция': 1977,
#  'делимся': 662,
#  'постом': 1997,
#  'мной': 1392,
#  'мысли': 1447,
#  'хотели': 3005,
#  'которая': 1153,
#  'пообщаться': 1960,
#  'новую': 1572,
#  'интересующие': 982,
#  'красивых': 1175,
#  'xfilm': 256,
#  'пропустить': 2155,
#  'центре': 3039,
#  'единомышленников': 769,
#  'пятница': 2214,
#  'получать': 1928,
#  'лица': 1236,
#  'расскажем': 2279,
#  'недвижимости': 1521,
#  'вашу': 425,
#  'этих': 3116,
#  'основана': 1708,
#  'комментарии': 1118,
#  'марка': 1313,
#  'будущее': 394,
#  'магазины': 1298,
#  'about': 0,
#  'полезными': 1913,
#  'творчества': 2750,
#  'которому': 1158,
#  'прежнему': 2056,
#  'одна': 1654,
#  'детали': 672,
#  'собранные': 2548,
#  'доставкой': 732,
#  'тщательно': 2851,
#  'блог': 369,
#  'месяцев': 1360,
#  'очереди': 1779,
#  'уникальные': 2904,
#  'причинам': 2102,
#  'одежду': 1651,
#  'интересное': 974,
#  'наша': 1510,
#  'часть': 3053,
#  'to': 232,
#  'счастливой': 2715,
#  'девяностые': 646,
#  'официальном': 1772,
#  'флешмобов': 2967,
#  'простые': 2164,
#  'деятельности': 689,
#  'interesting': 116,
#  'красивее': 1167,
#  'рынка': 2376,
#  'домашних': 722,
#  'было': 404,
#  'поле': 1904,
#  'вопросов': 498,
#  'гель': 561,
#  'гарантируем': 559,
#  'развлекать': 2244,
#  'знаете': 901,
#  'она': 1673,
#  'ищешь': 1026,
#  'полезного': 1907,
#  'причин': 2101,
#  'подробнее': 1866,
#  'мне': 1384,
#  'уральского': 2914,
#  'развития': 2242,
#  'дикого': 698,
#  'рынке': 2377,
#  'ежедневный': 780,
#  'предложку': 2047,
#  'доставки': 731,
#  'поведение': 1832,
#  'примеры': 2083,
#  'модные': 1405,
#  'ответить': 1735,
#  'рассказываем': 2283,
#  'kino': 128,
#  'спортивный': 2627,
#  'дмитрий': 699,
#  'выбрать': 537,
#  'мероприятия': 1350,
#  'pub': 190,
#  'тобой': 2805,
#  'статьями': 2661,
#  'недели': 1523,
#  'поднимают': 1853,
#  'удаляются': 2874,
#  'дизайне': 695,
#  'молодых': 1416,
#  'плюс': 1829,
#  'пошлое': 2013,
#  'игра': 920,
#  'парк': 1790,
#  'человека': 3060,
#  'малышей': 1305,
#  'туров': 2846,
#  'социальных': 2608,
#  'рада': 2227,
#  'вкусных': 469,
#  'произойдет': 2148,
#  'кидайте': 1075,
#  'человеческого': 3063,
#  'темам': 2777,
#  'bbzj': 20,
#  'live': 135,
#  'шоу': 3100,
#  'научно': 1496,
#  'формы': 2976,
#  'foto': 76,
#  'задачи': 848,
#  'течение': 2798,
#  'известный': 936,
#  'практики': 2033,
#  'товаров': 2808,
#  'собирают': 2544,
#  'пн': 1831,
#  'руси': 2368,
#  'мероприятий': 1349,
#  'разнятся': 2265,
#  'ракурса': 2272,
#  'ценности': 3035,
#  'петербург': 1809,
#  'протяжении': 2169,
#  'люди': 1288,
#  'советы': 2562,
#  'ярких': 3142,
#  'формат': 2971,
#  'конкурс': 1132,
#  'екатеринбургу': 785,
#  'интеллект': 966,
#  'отбор': 1731,
#  'музыка': 1436,
#  'имя': 953,
#  'формата': 2972,
#  'любой': 1278,
#  'современных': 2570,
#  'сейчас': 2454,
#  'собственной': 2552,
#  'фитнес': 2966,
#  'смысл': 2534,
#  'проходит': 2177,
#  'драма': 741,
#  'проводили': 2114,
#  'project': 186,
#  'равно': 2226,
#  'начать': 1505,
#  'качественные': 1066,
#  'магазинах': 1295,
#  'днем': 701,
#  'совсем': 2571,
#  'наслаждаться': 1481,
#  'игры': 926,
#  'marvel': 146,
#  'либо': 1229,
#  'снг': 2538,
#  'впечатлительны': 507,
#  'грусть': 612,
#  'ежедневную': 778,
#  'читать': 3078,
#  'авторов': 279,
#  'вопрос': 496,
#  'чтоб': 3083,
#  'телефон': 2769,
#  'опытных': 1692,
#  'коллекция': 1110,
#  'следующие': 2505,
#  'love': 137,
#  'известных': 937,
#  'конкурсах': 1133,
#  'организация': 1696,
#  'найдёте': 1463,
#  'профессиональных': 2176,
#  'угодно': 2869,
#  'номера': 1580,
#  'лайк': 1214,
#  'авторский': 281,
#  'ознакомьтесь': 1665,
#  'отправить': 1763,
#  'два': 636,
#  'возможно': 484,
#  'куда': 1198,
#  'подписывайся': 1862,
#  'этого': 3117,
#  'крупное': 1191,
#  'млн': 1383,
#  'средств': 2635,
#  'центры': 3040,
#  'проводятся': 2117,
#  'соответствующие': 2592,
#  'задаваемые': 842,
#  'голову': 582,
#  'типичного': 2801,
#  'приму': 2084,
#  'стене': 2662,
#  'правилам': 2022,
#  'развитии': 2240,
#  'дарит': 631,
#  'soul': 213,
#  'оставить': 1718,
#  'добавляйте': 706,
#  'метро': 1362,
#  'впервые': 505,
#  'правительством': 2028,
#  'общения': 1634,
#  'su': 220,
#  'специалистов': 2616,
#  'канал': 1050,
#  'repost': 198,
#  'всеми': 516,
#  'доверяют': 711,
#  'faq': 68,
#  'курсы': 1209,
#  'html': 103,
#  'нее': 1525,
#  'фабрика': 2947,
#  'мероприятиях': 1351,
#  'кем': 1074,
#  'современная': 2564,
#  'хитрости': 2993,
#  'фильма': 2961,
#  'астрологии': 330,
#  'искусстве': 1001,
#  'языке': 3137,
#  'твоей': 2742,
#  'бесплатное': 352,
#  'волосами': 493,
#  'целью': 3028,
#  'любят': 1286,
#  'компаний': 1126,
#  'проверенных': 2112,
#  'территории': 2790,
#  'блюд': 370,
#  'покупке': 1901,
#  'общаться': 1631,
#  'фан': 2950,
#  'приятного': 2104,
#  'прослушивания': 2157,
#  'единственный': 771,
#  'действительно': 648,
#  'дружище': 753,
#  'страх': 2694,
#  'узнавать': 2887,
#  'встречу': 523,
#  'присылайте': 2096,
#  'создание': 2579,
#  'участникам': 2936,
#  'открыть': 1756,
#  'ценителей': 3034,
#  'сб': 2407,
#  'хиты': 2994,
#  'пора': 1973,
#  'смешное': 2525,
#  'поставленной': 1991,
#  'важно': 408,
#  'имеет': 947,
#  'график': 606,
#  'самой': 2395,
#  'дизайн': 693,
#  'бот': 383,
#  'контент': 1141,
#  'the': 227,
#  'кого': 1105,
#  'командой': 1114,
#  'модных': 1407,
#  'билеты': 361,
#  'домой': 725,
#  'таким': 2728,
#  'handmade': 94,
#  'странах': 2681,
#  'секрет': 2455,
#  'бан': 340,
#  'присоединяйся': 2094,
#  'ссылку': 2644,
#  'ok': 167,
#  'странности': 2691,
#  'взорвем': 451,
#  'приложении': 2081,
#  'используйте': 1009,
#  'мышление': 1448,
#  'кошек': 1165,
#  'таких': 2730,
#  'разных': 2264,
#  'используем': 1008,
#  'проекте': 2141,
#  'big': 27,
#  'стесняйтесь': 2665,
#  'впечатлениями': 506,
#  'сочетаются': 2609,
#  'каким': 1044,
#  'четверг': 3069,
#  'ежеминутно': 781,
#  'подслушано': 1870,
#  'кнопку': 1102,
#  'участвуйте': 2933,
#  'рекомендуют': 2317,
#  'your': 260,
#  'проведения': 2110,
#  'кухня': 1212,
#  'основные': 1713,
#  'деньги': 669,
#  'афоризмы': 338,
#  'службы': 2516,
#  'пишите': 1819,
#  'поводу': 1834,
#  'работе': 2224,
#  'cтраница': 43,
#  'отношениях': 1762,
#  'котором': 1157,
#  'просмотров': 2159,
#  'диеты': 692,
#  'ведь': 432,
#  'представлены': 2052,
#  'опубликуем': 1688,
#  'разницу': 2262,
#  'семинары': 2461,
#  'do': 53,
#  'никогда': 1551,
#  'make': 140,
#  'сами': 2391,
#  'фотография': 2981,
#  'рады': 2233,
#  'удивительные': 2877,
#  'запрещены': 872,
#  'радостью': 2231,
#  'настоящий': 1487,
#  'целей': 3022,
#  'однако': 1655,
#  'администратора': 285,
#  'bon': 31,
#  'хотим': 3006,
#  'москва': 1422,
#  'законы': 856,
#  'участники': 2938,
#  'конечно': 1131,
#  'море': 1421,
#  'игрушки': 925,
#  'потому': 2003,
#  'команда': 1112,
#  'могу': 1396,
#  'science': 205,
#  'клиента': 1083,
#  'комиксы': 1117,
#  'знания': 909,
#  'сразу': 2633,
#  'семейный': 2460,
#  'цене': 3032,
#  'ucsettyknplsthhbbresg': 237,
#  'публикуем': 2198,
#  'сделаем': 2443,
#  'автомобили': 273,
#  'остается': 1722,
#  'поделки': 1852,
#  'мужчины': 1435,
#  'даром': 632,
#  'сериал': 2473,
#  'дизайнеров': 696,
#  'публикуется': 2199,
#  'своей': 2427,
#  'слова': 2509,
#  'school': 203,
#  'компанией': 1124,
#  'group': 93,
#  'удаляем': 2871,
#  'люблю': 1273,
#  'качеству': 1069,
#  'aliexpress': 5,
#  'facts': 67,
#  'чувствовать': 3085,
#  'удовольствие': 2882,
#  'humour': 105,
#  'бы': 399,
#  'варианты': 415,
#  'видеоматериалы': 456,
#  'размещать': 2257,
#  'объединяет': 1639,
#  'природа': 2090,
#  'ценит': 3033,
#  'путешествия': 2207,
#  'фильмы': 2964,
#  'третьяковой': 2837,
#  'деле': 661,
#  'стремимся': 2695,
#  'вся': 528,
#  'комментах': 1121,
#  'товар': 2806,
#  'часто': 3052,
#  'каждого': 1034,
#  'задач': 846,
#  'продукцию': 2136,
#  'говорят': 577,
#  'выходит': 551,
#  'дом': 719,
#  'августа': 267,
#  'тематики': 2779,
#  'осень': 1702,
#  'вниманию': 477,
#  'приятно': 2103,
#  'могут': 1397,
#  'каждая': 1033,
#  'хотят': 3010,
#  'ведущих': 431,
#  'home': 99,
#  'увлекательные': 2866,
#  'автоматически': 271,
#  'красивое': 1170,
#  'состоит': 2595,
#  'челябинск': 3065,
#  'питания': 1816,
#  'совпадает': 2563,
#  'жми': 829,
#  'движение': 638,
#  'умный': 2900,
#  'палатой': 1786,
#  'опыта': 1691,
#  'сатиры': 2406,
#  'одном': 1661,
#  'канала': 1051,
#  'стиле': 2666,
#  'две': 637,
#  'выходной': 552,
#  'разместить': 2254,
#  'arcazm': 14,
#  'семьи': 2463,
#  'газета': 557,
#  'путешественников': 2204,
#  'great': 92,
#  'отзывчивых': 1747,
#  'носит': 1583,
#  'того': 2811,
#  'силы': 2484,
#  'модераторов': 1403,
#  'путеводитель': 2203,
#  'яндекс': 3140,
#  'постоянно': 1998,
#  'borsch': 33,
#  'ищите': 1027,
#  'вызывает': 540,
#  'подать': 1841,
#  'пышма': 2213,
#  'приложение': 2080,
#  'афиша': 337,
#  'проблемы': 2107,
#  'google': 91,
#  'auto': 18,
#  'такая': 2726,
#  'попутчиков': 1971,
#  'верим': 436,
#  'познавательно': 1882,
#  'душа': 760,
#  'инфу': 995,
#  'откровениями': 1754,
#  'beauty': 22,
#  'journal': 123,
#  'сотрудничества': 2600,
#  'полезное': 1908,
#  'ценам': 3031,
#  'меню': 1345,
#  'магазин': 1293,
#  'записаться': 865,
#  'лепру': 1224,
#  'эту': 3121,
#  'no': 163,
#  'девушки': 645,
#  'история': 1019,
#  'макияжа': 1300,
#  'клиенты': 1086,
#  'официальную': 1773,
#  'увидел': 2863,
#  'реальности': 2291,
#  'оформление': 1776,
#  'ios': 118,
#  'еженедельные': 782,
#  'комментарий': 1119,
#  'друзья': 755,
#  'описать': 1680,
#  'сотрудничество': 2602,
#  'brain': 34,
#  'хочешь': 3013,
#  'посты': 2000,
#  'призов': 2076,
#  'бесплатной': 353,
#  'группах': 609,
#  'сергей': 2470,
#  'одним': 1656,
#  'женственность': 810,
#  'живите': 816,
#  'месяца': 1359,
#  'администрации': 289,
#  'любым': 1284,
#  'оружие': 1701,
#  'ребят': 2296,
#  'изменения': 942,
#  'невероятные': 1518,
#  'площадка': 1827,
#  'менеджеру': 1342,
#  'городе': 589,
#  'запостить': 868,
#  'самим': 2392,
#  'гостей': 599,
#  'специально': 2618,
#  'познавательное': 1883,
#  'подарков': 1839,
#  'предлагать': 2041,
#  'школе': 3095,
#  'cc': 37,
#  'причесок': 2100,
#  'покупателей': 1898,
#  'городом': 591,
#  'счастья': 2718,
#  'особенно': 1715,
#  'слишком': 2507,
#  'меньше': 1344,
#  'пока': 1893,
#  'настроение': 1489,
#  'твой': 2745,
#  'несчастного': 1537,
#  'разделе': 2248,
#  'урал': 2910,
#  'мистика': 1381,
#  'большую': 382,
#  'сайте': 2384,
#  'world': 253,
#  'радио': 2228,
#  'мирового': 1375,
#  'купить': 1203,
#  'incekb': 112,
#  'затем': 878,
#  'качестве': 1063,
#  'адресу': 294,
#  'регулярно': 2299,
#  'обращаться': 1614,
#  'лайки': 1215,
#  'использовании': 1005,
#  'участвовать': 2932,
#  'любить': 1271,
#  'получите': 1932,
#  'exclusive': 63,
#  'заходи': 880,
#  'смыслом': 2536,
#  'помощь': 1951,
#  'sport': 215,
#  'несет': 1534,
#  'хоп': 2996,
#  'когда': 1104,
#  'между': 1338,
#  'картинок': 1055,
#  'sci': 204,
#  'пожелания': 1876,
#  'посмотреть': 1987,
#  'мечты': 1363,
#  'которого': 1154,
#  'настроения': 1491,
#  'изделий': 940,
#  'ночь': 1584,
#  'ограничиваем': 1646,
#  'ту': 2842,
#  'благодарность': 363,
#  'ольга': 1671,
#  'выходные': 553,
#  'mam': 141,
#  'поможем': 1947,
#  'клуба': 1089,
#  'сама': 2389,
#  'автора': 278,
#  'кнопкой': 1101,
#  'фотографии': 2979,
#  'философия': 2959,
#  'зал': 858,
#  'входит': 532,
#  'рекламе': 2309,
#  'стоимости': 2671,
#  'собраны': 2549,
#  'позволяет': 1877,
#  'столицы': 2675,
#  'пр': 2017,
#  'минут': 1373,
#  'совершенно': 2558,
#  'времени': 511,
#  'ремонту': 2320,
#  'интеллигенция': 968,
#  'пользуйся': 1939,
#  'моделей': 1400,
#  'волосы': 494,
#  'фотографиями': 2982,
#  'решением': 2332,
#  'album': 3,
#  'контакты': 1140,
#  'другими': 746,
#  'сeргeю': 2380,
#  'беременность': 348,
#  'кусочек': 1210,
#  'индивидуальный': 958,
#  'отзывы': 1748,
#  'обсуждений': 1621,
#  'год': 578,
#  'уникальное': 2903,
#  ...}

# %%
vec.get_params()
# Out:
# {'analyzer': 'word',
#  'binary': False,
#  'decode_error': 'strict',
#  'dtype': numpy.float64,
#  'encoding': 'utf-8',
#  'input': 'content',
#  'lowercase': True,
#  'max_df': 0.35,
#  'max_features': None,
#  'min_df': 0.025,
#  'ngram_range': (1, 1),
#  'norm': 'l2',
#  'preprocessor': None,
#  'smooth_idf': True,
#  'stop_words': None,
#  'strip_accents': None,
#  'sublinear_tf': False,
#  'token_pattern': '(?u)\\b\\w\\w+\\b',
#  'tokenizer': None,
#  'use_idf': True,
#  'vocabulary': None}

# %%
'кино' in vec.vocabulary_
# Out:
# True

# %%
'музыка' in vec.vocabulary_
# Out:
# True

# %%
vec.get_params()
# Out:
# {'analyzer': 'word',
#  'binary': False,
#  'decode_error': 'strict',
#  'dtype': numpy.float64,
#  'encoding': 'utf-8',
#  'input': 'content',
#  'lowercase': True,
#  'max_df': 0.4,
#  'max_features': None,
#  'min_df': 10,
#  'ngram_range': (1, 1),
#  'norm': 'l2',
#  'preprocessor': None,
#  'smooth_idf': True,
#  'stop_words': None,
#  'strip_accents': None,
#  'sublinear_tf': False,
#  'token_pattern': '(?u)\\b\\w\\w+\\b',
#  'tokenizer': None,
#  'use_idf': True,
#  'vocabulary': None}

# %%
len(vec.get_feature_names())
# Out:
# 207624

# %%
from clustering import save_model
from sklearn.decomposition import TruncatedSVD
pca = TruncatedSVD()
save_model(pca, 'pca.pkl')

# %%
from clustering import load_model
pca = load_model('pca.pkl')
pca.get_params()
# Out:
# {'algorithm': 'randomized',
#  'n_components': 2,
#  'n_iter': 5,
#  'random_state': None,
#  'tol': 0.0}
